# %%
# Python program to explain cv2.circle() method

# importing cv2
import cv2

# path
path = 'CR6008_02GR_L2_2019-05-24-141302-0002.jpg'

# Reading an image in default mode
image = cv2.imread(path)

# Window name in which image is displayed
window_name = 'Image'

# Center coordinates
center_coordinates = (120, 50)

# Radius of circle
radius = 20

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.circle() method
# Draw a circle with blue line borders of thickness of 2 px
image = cv2.circle(image, center_coordinates, radius, color, thickness)

# Displaying the image
cv2.imshow(window_name, image)

# %%
import cv2

# path
path = 'CR6008_02GR_L2_2019-05-24-141302-0002.jpg'

# Reading an image in default mode
img = cv2.imread(path)


img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# make a copy of the original image
cimg = img.copy()

# %%
pip install importlib-metadata
# Out:
# Requirement already satisfied: importlib-metadata in c:\users\sreelaxmi\appdata\local\continuum\anaconda3\lib\site-packages (0.0.0)
# Requirement already satisfied: zipp>=0.3.2 in c:\users\sreelaxmi\appdata\local\continuum\anaconda3\lib\site-packages (from importlib-metadata) (0.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray,(5,5),0)
inv = cv2.bitwise_not(blur)
plt.imshow(inv, cmap="gray")
plt.show()

# %%
import argparse
ap = argparse.ArgumentParser()

# %%
ap.add_argument("-i", "--image", required = True, help = "Path to the image")
# Out:
# _StoreAction(option_strings=['-i', '--image'], dest='image', nargs=None, const=None, default=None, type=None, choices=None, help='Path to the image', metavar=None)

# %%
# import sys
# print(sys.argv)
# import sys
# sys.argv = ['run.py']
# Out:
# ['C:\\Users\\Sreelaxmi\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\Sreelaxmi\\AppData\\Roaming\\jupyter\\runtime\\kernel-aed68c65-716e-4323-81a7-b4aaeb6bcd7c.json']

# %%
# args = vars(ap.parse_args())
# Out:
# usage: ipykernel_launcher.py [-h] -i IMAGE
# ipykernel_launcher.py: error: the following arguments are required: -i/--image
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
circles = cv2.HoughCircles(inv, cv2.HOUGH_GRADIENT, 1.2, 100)

# %%
if circles is not None:
	# convert the (x, y) coordinates and radius of the circles to integers
	circles = np.round(circles[0, :]).astype("int")
	# loop over the (x, y) coordinates and radius of the circles
	for (x, y, r) in circles:
		# draw the circle in the output image, then draw a rectangle
		# corresponding to the center of the circle
		cv2.circle(output, (x, y), r, (0, 255, 0), 4)
		cv2.rectangle(output, (x - 5, y - 5), (x + 5, y + 5), (0, 128, 255), -1)
	# show the output image
	cv2.imshow("output", np.hstack([image, output]))
	cv2.waitKey(0)

# %%
cv2.circle(img,(100, 0), 25, (0,255,0))
# Out:
# array([[21,  9,  7, ...,  9,  9,  9],
#        [11,  7,  7, ...,  9,  9,  9],
#        [ 7,  6,  6, ...,  8,  8,  8],
#        ...,
#        [ 3,  3,  3, ...,  5,  5,  5],
#        [ 3,  3,  3, ...,  5,  5,  5],
#        [ 3,  3,  3, ...,  5,  4,  4]], dtype=uint8)

# %%
import cv2 
cv2.circle(img,(500, 500), 300, (255,0,0), 3)
 
cv2.imshow('Test image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
