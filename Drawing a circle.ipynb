# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image 
import PIL 

# path
path = 'CR6008_00TS_L1_I1_2019-04-03-141254-0001.jpg'

# Reading an image in default mode
image = cv2.imread(path)

# Window name in which image is displayed
# window_name = 'Image'

# Center coordinates
center_coordinates = (756, 600)

# Radius of circle
radius = 435

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.circle() method
# Draw a circle with blue line borders of thickness of 2 px
image = cv2.circle(image, center_coordinates, radius, color, thickness)

image = cv2.circle(image, (756,600), 5, color, -1)


# cv2.imshow('Eye', image) # Displaying the image
#saving the image
filename = "test_eye_image_1.jpg"
cv2.imwrite(filename, image)
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image 
import PIL 

# path
path = 'CR6008_02GR_L2_2019-05-24-141302-0002.jpg'

# Reading an image in default mode
image = cv2.imread(path)

# Window name in which image is displayed
# window_name = 'Image'

# Center coordinates
center_coordinates = (756, 400)

# Radius of circle
radius = 435

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.circle() method
# Draw a circle with blue line borders of thickness of 2 px
image = cv2.circle(image, center_coordinates, radius, color, thickness)

image = cv2.circle(image, (756,400), 5, color, -1)


# cv2.imshow('Eye', image) # Displaying the image
#saving the image
filename = "test_eye_image_2.jpg"
cv2.imwrite(filename, image)
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.show()

# %%
# Python program to explain cv2.circle() method

# importing cv2
import cv2
import matplotlib.pyplot as plt

# path
path = 'DSC_0508.jpg'

# Reading an image in default mode
image = cv2.imread(path)

# Window name in which image is displayed
window_name = 'Image'

# Center coordinates
center_coordinates = (2120, 1200)

# Radius of circle
radius = 400

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.circle() method
# Draw a circle with blue line borders of thickness of 2 px
image = cv2.circle(image, center_coordinates, radius, color, thickness)

filename = "test_eye_image_3.jpg"
cv2.imwrite(filename, image)

rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.show()

# Displaying the image
# cv2.imshow(window_name, image)

# %%
# Python program to explain cv2.circle() method

# importing cv2
import cv2
import matplotlib.pyplot as plt

# path
path = 'data/frame0.jpg'

# Reading an image in default mode
image = cv2.imread(path)

# Window name in which image is displayed
window_name = 'Image'

# Center coordinates
center_coordinates = (750, 480)

# Radius of circle
radius = 450

# Blue color in BGR
color = (255, 0, 0)

# Line thickness of 2 px
thickness = 2

# Using cv2.circle() method
# Draw a circle with blue line borders of thickness of 2 px
image = cv2.circle(image, center_coordinates, radius, color, thickness)

filename = "test_eye_image_4.jpg"
cv2.imwrite(filename, image)

rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.grid()
plt.show()

# Displaying the image
# cv2.imshow(window_name, image)
